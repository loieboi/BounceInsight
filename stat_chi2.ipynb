# %%
import sys
import os
current_dir = os.path.dirname(os.path.abspath('__file__'))
print(f'Current Directory: {current_dir}')
root_dir = os.path.abspath(os.path.join(current_dir, '..'))

if os.path.exists(root_dir):
    print(f'Root Directory exists: {root_dir}')
else:
    print(f'Root Directory does NOT exist: {root_dir}')
    

if root_dir not in sys.path:
    sys.path.append(root_dir)
    
try:
    from BounceInsight import BounceInsight
    print("Successfully imported BounceInsight")
except ModuleNotFoundError as e:
    print(f"BounceInsight module not found. Please check the module path. {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    
try:
    # %reload_ext autoreload
except:
    # %load_ext autoreload

# %autoreload 2
    
csv_path = os.path.abspath(os.path.join(current_dir, 'files/loader'))
insight = BounceInsight(csv_path, "bounce")
# Out:
# Current Directory: C:\Users\timos\Desktop\BounceInsight
# Root Directory exists: C:\Users\timos\Desktop
# Successfully imported BounceInsight

# %%
print('=============================================================================================================')
print('================================ OVERALL ANOVA (Dip Analysis) ===============================================')
print('=============================================================================================================')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_70')
print('')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_80')
print('')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_slow')
print('')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_fast')
print('')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_all')
# Out:
# ...
# ================================ OVERALL ANOVA (Dip Analysis) ===============================================
# ...
# Contingency Table:
# has_dip     False  True
# group
# bounce70b      51     58
# bounce70nb     94     14
# Chi-Square Test:
# Chi2: 37.84226813487228, p-value: 7.670177262350758e-10, Degrees of Freedom: 1
# Plot saved to files/plots\chi2_None_b_nb_70.png
# Contingency Table:
# has_dip     False  True
# group
# bounce80b      52     56
# bounce80nb     96     11
# Chi-Square Test:
# Chi2: 41.385009763477385, p-value: 1.2501235884064362e-10, Degrees of Freedom: 1
# Plot saved to files/plots\chi2_None_b_nb_80.png
# Contingency Table:
# has_dip  False  True
# group
# slowb        7     80
# slownb      69     18
# Chi-Square Test:
# Chi2: 86.92991407089151, p-value: 1.1243581053586438e-20, Degrees of Freedom: 1
# Plot saved to files/plots\chi2_None_b_nb_slow.png
# Contingency Table:
# has_dip  False  True
# group
# fastb       32     55
# fastnb      77      8
# ...

# %%
print('=============================================================================================================')
print('================================ FEMALE ANOVA (Dip Analysis) ================================================')
print('=============================================================================================================')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_70', gender='f')
print('')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_80', gender='f')
print('')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_slow', gender='f')
print('')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_fast', gender='f')
print('')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_all', gender='f')
# Out:
# ...
# ================================ FEMALE ANOVA (Dip Analysis) ================================================
# ...
# Contingency Table:
# has_dip     False  True
# group
# bounce70b      29     19
# bounce70nb     45      3
# Chi-Square Test:
# Chi2: 13.267813267813267, p-value: 0.0002700019671972031, Degrees of Freedom: 1
# Plot saved to files/plots\chi2_None_b_nb_70.png
# Contingency Table:
# has_dip     False  True
# group
# bounce80b      30     18
# bounce80nb     45      2
# Chi-Square Test:
# Chi2: 13.854342124704491, p-value: 0.00019753976156200114, Degrees of Freedom: 1
# Plot saved to files/plots\chi2_None_b_nb_80.png
# Contingency Table:
# has_dip  False  True
# group
# slowb        2     37
# slownb      36      3
# Chi-Square Test:
# Chi2: 55.882894736842104, p-value: 7.69188989561033e-14, Degrees of Freedom: 1
# Plot saved to files/plots\chi2_None_b_nb_slow.png
# Contingency Table:
# has_dip  False  True
# group
# fastb       18     21
# fastnb      36      1
# ...

# %%
print('=============================================================================================================')
print('================================ MALE ANOVA (Dip Analysis) ==================================================')
print('=============================================================================================================')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_70', gender='m')
print('')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_80', gender='m')
print('')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_slow', gender='m')
print('')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_fast', gender='m')
print('')
insight.run_statistics(analysis_type='chi2', comparison_type='b_nb_all', gender='m')
# Out:
# ...
# ================================ MALE ANOVA (Dip Analysis) ==================================================
# ...
# Contingency Table:
# has_dip     False  True
# group
# bounce70b      22     39
# bounce70nb     49     11
# Chi-Square Test:
# Chi2: 24.09450798506888, p-value: 9.17215164983183e-07, Degrees of Freedom: 1
# Plot saved to files/plots\chi2_None_b_nb_70.png
# Contingency Table:
# has_dip     False  True
# group
# bounce80b      22     38
# bounce80nb     51      9
# Chi-Square Test:
# Chi2: 27.420577091227052, p-value: 1.6368029959952385e-07, Degrees of Freedom: 1
# Plot saved to files/plots\chi2_None_b_nb_80.png
# Contingency Table:
# has_dip  False  True
# group
# slowb        5     43
# slownb      33     15
# Chi-Square Test:
# Chi2: 31.75317604355717, p-value: 1.7506274988605296e-08, Degrees of Freedom: 1
# Plot saved to files/plots\chi2_None_b_nb_slow.png
# Contingency Table:
# has_dip  False  True
# group
# fastb       14     34
# fastnb      41      7
# ...
