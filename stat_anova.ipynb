# %%
import sys
import os
current_dir = os.path.dirname(os.path.abspath('__file__'))
print(f'Current Directory: {current_dir}')
root_dir = os.path.abspath(os.path.join(current_dir, '..'))

if os.path.exists(root_dir):
    print(f'Root Directory exists: {root_dir}')
else:
    print(f'Root Directory does NOT exist: {root_dir}')
    

if root_dir not in sys.path:
    sys.path.append(root_dir)
    
try:
    from BounceInsight import BounceInsight
    print("Successfully imported BounceInsight")
except ModuleNotFoundError as e:
    print(f"BounceInsight module not found. Please check the module path. {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    
try:
    # %reload_ext autoreload
except:
    # %load_ext autoreload

# %autoreload 2
    
csv_path = os.path.abspath(os.path.join(current_dir, 'files/loader'))
insight = BounceInsight(csv_path, "bounce")
# Out:
# Current Directory: C:\Users\timos\Desktop\BounceInsight
# Root Directory exists: C:\Users\timos\Desktop
# Successfully imported BounceInsight

# %%
insight.run_statistics(analysis_type='anova', metric='t_ecc', df_type='fp')
# Out:
#                    Anova
# ...
#               F Value  Num DF  Den DF Pr > F
# --------------------------------------------
# cue           216.3942 1.0000 28.0000 0.0000
# condition      43.9832 1.0000 28.0000 0.0000
# cue:condition   5.0924 1.0000 28.0000 0.0320
# ...
#
# Performing post-hoc tests for 'cue'
# Comparison between fast and slow: t=-18.820, p=0.0000, significant=True, Cohen's d=-2.706
# Performing post-hoc tests for 'condition'
# Comparison between bounce and nobounce: t=-6.546, p=0.0000, significant=True, Cohen's d=-0.346

# %%
print('=============================================================================================================')
print('================================ OVERALL ANOVA (Lowering Cue) ===============================================')
print('=============================================================================================================')
insight.run_statistics(analysis_type='anova', metric='t_ecc', df_type='fp')
print('')
insight.run_statistics(analysis_type='anova', metric='mVe', df_type='gym')
print('')
insight.run_statistics(analysis_type='anova', metric='tpV', df_type='gym')
print('')
insight.run_statistics(analysis_type='anova', metric='pVc', df_type='gym')
print('')
insight.run_statistics(analysis_type='anova', metric='mVc', df_type='gym')
print('')
insight.run_statistics(analysis_type='anova', metric='tpP', df_type='gym')
print('')
insight.run_statistics(analysis_type='anova', metric='pPc', df_type='gym')
print('')
insight.run_statistics(analysis_type='anova', metric='mPc', df_type='gym')
print('')
insight.run_statistics(analysis_type='anova', metric='lD_m', df_type='gym')
# Out:
# ...
# ================================ OVERALL ANOVA (Lowering Cue) ===============================================
# ...
#                    Anova
# ...
#               F Value  Num DF  Den DF Pr > F
# --------------------------------------------
# cue           216.3942 1.0000 28.0000 0.0000
# condition      43.9832 1.0000 28.0000 0.0000
# cue:condition   5.0924 1.0000 28.0000 0.0320
# ...
#
# Performing post-hoc tests for 'cue'
# Comparison between fast and slow: t=-18.820, p=0.0000, significant=True, Cohen's d=-2.706
# Performing post-hoc tests for 'condition'
# Comparison between bounce and nobounce: t=-6.546, p=0.0000, significant=True, Cohen's d=-0.346
#                    Anova
# ...
#               F Value  Num DF  Den DF Pr > F
# --------------------------------------------
# cue           358.7305 1.0000 28.0000 0.0000
# condition      71.5128 1.0000 28.0000 0.0000
# cue:condition  10.1316 1.0000 28.0000 0.0036
# ...
#
# Performing post-hoc tests for 'cue'
# ...

# %%
print('=============================================================================================================')
print('================================ FEMALE ANOVA (Lowering Cue) ================================================')
print('=============================================================================================================')
insight.run_statistics(analysis_type='anova', metric='t_ecc', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='anova', metric='mVe', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='anova', metric='tpV', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='anova', metric='pVc', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='anova', metric='mVc', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='anova', metric='tpP', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='anova', metric='pPc', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='anova', metric='mPc', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='anova', metric='lD_m', df_type='gym', gender='f')
# Out:
# ...
# ================================ FEMALE ANOVA (Lowering Cue) ================================================
# ...
#                    Anova
# ...
#               F Value Num DF  Den DF Pr > F
# -------------------------------------------
# cue           89.6814 1.0000 12.0000 0.0000
# condition     24.8795 1.0000 12.0000 0.0003
# cue:condition  3.6491 1.0000 12.0000 0.0803
# ...
#
# Performing post-hoc tests for 'cue'
# Comparison between fast and slow: t=-12.127, p=0.0000, significant=True, Cohen's d=-2.831
# Performing post-hoc tests for 'condition'
# Comparison between bounce and nobounce: t=-4.465, p=0.0001, significant=True, Cohen's d=-0.355
#                    Anova
# ...
#               F Value  Num DF  Den DF Pr > F
# --------------------------------------------
# cue           179.7591 1.0000 12.0000 0.0000
# condition      42.0424 1.0000 12.0000 0.0000
# cue:condition   4.1793 1.0000 12.0000 0.0635
# ...
#
# Performing post-hoc tests for 'cue'
# ...

# %%
print('=============================================================================================================')
print('================================ MALE ANOVA (Lowering Cue) ==================================================')
print('=============================================================================================================')
insight.run_statistics(analysis_type='anova', metric='t_ecc', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='anova', metric='mVe', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='anova', metric='tpV', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='anova', metric='pVc', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='anova', metric='mVc', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='anova', metric='tpP', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='anova', metric='pPc', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='anova', metric='mPc', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='anova', metric='lD_m', df_type='gym', gender='m')
# Out:
# ...
# ================================ MALE ANOVA (Lowering Cue) ==================================================
# ...
#                    Anova
# ...
#               F Value  Num DF  Den DF Pr > F
# --------------------------------------------
# cue           121.8652 1.0000 15.0000 0.0000
# condition      19.2129 1.0000 15.0000 0.0005
# cue:condition   1.5486 1.0000 15.0000 0.2324
# ...
#
# Paired t-test for slow cue: t=-3.516, p=0.0031
# Paired t-test for fast cue: t=-3.270, p=0.0052
# Performing post-hoc tests for 'cue'
# Comparison between fast and slow: t=-14.364, p=0.0000, significant=True, Cohen's d=-2.633
# Performing post-hoc tests for 'condition'
# Comparison between bounce and nobounce: t=-4.714, p=0.0000, significant=True, Cohen's d=-0.336
#                    Anova
# ...
#               F Value  Num DF  Den DF Pr > F
# --------------------------------------------
# cue           182.7114 1.0000 15.0000 0.0000
# condition      31.3975 1.0000 15.0000 0.0001
# ...
