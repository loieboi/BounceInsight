# %%
import sys
import os
current_dir = os.path.dirname(os.path.abspath('__file__'))
print(f'Current Directory: {current_dir}')
root_dir = os.path.abspath(os.path.join(current_dir, '..'))

if os.path.exists(root_dir):
    print(f'Root Directory exists: {root_dir}')
else:
    print(f'Root Directory does NOT exist: {root_dir}')
    

if root_dir not in sys.path:
    sys.path.append(root_dir)
    
try:
    from BounceInsight import BounceInsight
    print("Successfully imported BounceInsight")
except ModuleNotFoundError as e:
    print(f"BounceInsight module not found. Please check the module path. {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    
try:
    # %reload_ext autoreload
except:
    # %load_ext autoreload

# %autoreload 2
    
csv_path = os.path.abspath(os.path.join(current_dir, 'files/loader'))
insight = BounceInsight(csv_path, "bounce")
# Out:
# Current Directory: C:\Users\timos\Desktop\BounceInsight
# Root Directory exists: C:\Users\timos\Desktop
# Successfully imported BounceInsight

# %%
print('=============================================================================================================')
print('================================ OVERALL PAIRED TTESTS (Bounce vs No Bounce) ================================')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='F_turning_norm', comparison_type='b_nb_70', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='F_turning_norm', comparison_type='b_nb_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='F_turning', comparison_type='b_nb_70', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='F_turning', comparison_type='b_nb_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='t_ecc', comparison_type='b_nb_70', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='t_ecc', comparison_type='b_nb_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='t_con', comparison_type='b_nb_70', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='t_con', comparison_type='b_nb_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='tpP', comparison_type='b_nb_70', df_type='gym')
print('')
insight.run_statistics(analysis_type='ttest', metric='tpP', comparison_type='b_nb_80', df_type='gym')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='tpV', comparison_type='b_nb_70', df_type='gym')
print('')
insight.run_statistics(analysis_type='ttest', metric='tpV', comparison_type='b_nb_80', df_type='gym')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con_norm', comparison_type='b_nb_70', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con_norm', comparison_type='b_nb_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con', comparison_type='b_nb_70', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con', comparison_type='b_nb_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='P_mean_con', comparison_type='b_nb_70', df_type='gym')
print('')
insight.run_statistics(analysis_type='ttest', metric='P_mean_con', comparison_type='b_nb_80', df_type='gym')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='V_mean_con', comparison_type='b_nb_70', df_type='gym')
print('')
insight.run_statistics(analysis_type='ttest', metric='V_mean_con', comparison_type='b_nb_80', df_type='gym')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con_norm', comparison_type='b_nb_70', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con_norm', comparison_type='b_nb_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con', comparison_type='b_nb_70', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con', comparison_type='b_nb_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='P_peak_con', comparison_type='b_nb_70', df_type='gym')
print('')
insight.run_statistics(analysis_type='ttest', metric='P_peak_con', comparison_type='b_nb_80', df_type='gym')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='V_peak_con', comparison_type='b_nb_70', df_type='gym')
print('')
insight.run_statistics(analysis_type='ttest', metric='V_peak_con', comparison_type='b_nb_80', df_type='gym')
print('=============================================================================================================')
print('')
print('=============================================================================================================')
print('================================ OVERALL PAIRED TTESTS (70 vs 80) ===========================================')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='F_turning_norm', comparison_type='b_70_80', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='F_turning_norm', comparison_type='nb_70_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='F_turning', comparison_type='b_70_80', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='F_turning', comparison_type='nb_70_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='t_ecc', comparison_type='b_70_80', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='t_ecc', comparison_type='nb_70_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='t_con', comparison_type='b_70_80', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='t_con', comparison_type='nb_70_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='tpP', comparison_type='b_70_80', df_type='gym')
print('')
insight.run_statistics(analysis_type='ttest', metric='tpP', comparison_type='nb_70_80', df_type='gym')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='tpV', comparison_type='b_70_80', df_type='gym')
print('')
insight.run_statistics(analysis_type='ttest', metric='tpV', comparison_type='nb_70_80', df_type='gym')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con_norm', comparison_type='b_70_80', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con_norm', comparison_type='nb_70_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con', comparison_type='b_70_80', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con', comparison_type='nb_70_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='P_mean_con', comparison_type='b_70_80', df_type='gym')
print('')
insight.run_statistics(analysis_type='ttest', metric='P_mean_con', comparison_type='nb_70_80', df_type='gym')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='V_mean_con', comparison_type='b_70_80', df_type='gym')
print('')
insight.run_statistics(analysis_type='ttest', metric='V_mean_con', comparison_type='nb_70_80', df_type='gym')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con_norm', comparison_type='b_70_80', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con_norm', comparison_type='nb_70_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con', comparison_type='b_70_80', df_type='fp')
print('')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con', comparison_type='nb_70_80', df_type='fp')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='P_peak_con', comparison_type='b_70_80', df_type='gym')
print('')
insight.run_statistics(analysis_type='ttest', metric='P_peak_con', comparison_type='nb_70_80', df_type='gym')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='V_peak_con', comparison_type='b_70_80', df_type='gym')
print('')
insight.run_statistics(analysis_type='ttest', metric='V_peak_con', comparison_type='nb_70_80', df_type='gym')
print('=============================================================================================================')
# Out:
# ...
# ================================ OVERALL PAIRED TTESTS (Bounce vs No Bounce) ================================
# ...
# group  bounce70b  bounce70nb
# count  36.000000   36.000000
# mean    1.615281    1.326839
# std     0.182774    0.101907
# min     1.268271    1.126978
# 25%     1.457497    1.285530
# 50%     1.608602    1.335829
# 75%     1.733241    1.381203
# max     2.064517    1.554142
# Homogeneity of variances assumption is not met.
# Normality assumption is met for both groups.
# Assumptions not met for paired t-test. Using Wilcoxon signed-rank test instead.
# Wilcoxon Signed-Rank Test for F_turning_norm: statistic = 0.0, p-value = 2.9103830456733704e-11
#
# group  bounce80b  bounce80nb
# count  36.000000   36.000000
# mean    1.517965    1.290578
# std     0.168109    0.090111
# min     1.187362    1.122316
# 25%     1.384506    1.229333
# 50%     1.520040    1.285544
# 75%     1.609974    1.346314
# max     1.945035    1.561767
# Homogeneity of variances assumption is not met.
# ...

# %%
print('=============================================================================================================')
print('================================ FEMALE PAIRED TTESTS (Bounce vs No Bounce) ================================')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='F_turning_norm', comparison_type='b_nb_70', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='F_turning_norm', comparison_type='b_nb_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='F_turning', comparison_type='b_nb_70', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='F_turning', comparison_type='b_nb_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='t_ecc', comparison_type='b_nb_70', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='t_ecc', comparison_type='b_nb_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='t_con', comparison_type='b_nb_70', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='t_con', comparison_type='b_nb_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='tpP', comparison_type='b_nb_70', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='tpP', comparison_type='b_nb_80', df_type='gym', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='tpV', comparison_type='b_nb_70', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='tpV', comparison_type='b_nb_80', df_type='gym', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con_norm', comparison_type='b_nb_70', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con_norm', comparison_type='b_nb_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con', comparison_type='b_nb_70', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con', comparison_type='b_nb_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='P_mean_con', comparison_type='b_nb_70', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='P_mean_con', comparison_type='b_nb_80', df_type='gym', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='V_mean_con', comparison_type='b_nb_70', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='V_mean_con', comparison_type='b_nb_80', df_type='gym', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con_norm', comparison_type='b_nb_70', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con_norm', comparison_type='b_nb_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con', comparison_type='b_nb_70', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con', comparison_type='b_nb_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='P_peak_con', comparison_type='b_nb_70', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='P_peak_con', comparison_type='b_nb_80', df_type='gym', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='V_peak_con', comparison_type='b_nb_70', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='V_peak_con', comparison_type='b_nb_80', df_type='gym', gender='f')
print('=============================================================================================================')
print('')
print('=============================================================================================================')
print('================================ FEMALE PAIRED TTESTS (70 vs 80) ===========================================')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='F_turning_norm', comparison_type='b_70_80', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='F_turning_norm', comparison_type='nb_70_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='F_turning', comparison_type='b_70_80', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='F_turning', comparison_type='nb_70_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='t_ecc', comparison_type='b_70_80', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='t_ecc', comparison_type='nb_70_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='t_con', comparison_type='b_70_80', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='t_con', comparison_type='nb_70_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='tpP', comparison_type='b_70_80', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='tpP', comparison_type='nb_70_80', df_type='gym', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='tpV', comparison_type='b_70_80', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='tpV', comparison_type='nb_70_80', df_type='gym', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con_norm', comparison_type='b_70_80', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con_norm', comparison_type='nb_70_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con', comparison_type='b_70_80', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con', comparison_type='nb_70_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='P_mean_con', comparison_type='b_70_80', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='P_mean_con', comparison_type='nb_70_80', df_type='gym', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='V_mean_con', comparison_type='b_70_80', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='V_mean_con', comparison_type='nb_70_80', df_type='gym', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con_norm', comparison_type='b_70_80', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con_norm', comparison_type='nb_70_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con', comparison_type='b_70_80', df_type='fp', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con', comparison_type='nb_70_80', df_type='fp', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='P_peak_con', comparison_type='b_70_80', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='P_peak_con', comparison_type='nb_70_80', df_type='gym', gender='f')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='V_peak_con', comparison_type='b_70_80', df_type='gym', gender='f')
print('')
insight.run_statistics(analysis_type='ttest', metric='V_peak_con', comparison_type='nb_70_80', df_type='gym', gender='f')
print('=============================================================================================================')
# Out:
# ...
# ================================ FEMALE PAIRED TTESTS (Bounce vs No Bounce) ================================
# ...
# group  bounce70b  bounce70nb
# count  16.000000   16.000000
# mean    1.647921    1.317656
# std     0.205281    0.114998
# min     1.384384    1.126978
# 25%     1.466582    1.238771
# 50%     1.625456    1.335829
# 75%     1.746675    1.382094
# max     2.064517    1.529622
# Homogeneity of variances assumption is not met.
# Normality assumption is met for both groups.
# Assumptions not met for paired t-test. Using Wilcoxon signed-rank test instead.
# Wilcoxon Signed-Rank Test for F_turning_norm: statistic = 0.0, p-value = 3.0517578125e-05
#
# group  bounce80b  bounce80nb
# count  16.000000   16.000000
# mean    1.563019    1.307163
# std     0.186280    0.105748
# min     1.296337    1.143361
# 25%     1.410194    1.250913
# 50%     1.541348    1.302003
# 75%     1.660583    1.366290
# max     1.945035    1.561767
# Homogeneity of variances assumption is met.
# ...

# %%
print('=============================================================================================================')
print('================================ MALE PAIRED TTESTS (Bounce vs No Bounce) ===================================')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='F_turning_norm', comparison_type='b_nb_70', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='F_turning_norm', comparison_type='b_nb_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='F_turning', comparison_type='b_nb_70', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='F_turning', comparison_type='b_nb_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='t_ecc', comparison_type='b_nb_70', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='t_ecc', comparison_type='b_nb_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='t_con', comparison_type='b_nb_70', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='t_con', comparison_type='b_nb_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='tpP', comparison_type='b_nb_70', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='tpP', comparison_type='b_nb_80', df_type='gym', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='tpV', comparison_type='b_nb_70', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='tpV', comparison_type='b_nb_80', df_type='gym', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con_norm', comparison_type='b_nb_70', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con_norm', comparison_type='b_nb_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con', comparison_type='b_nb_70', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con', comparison_type='b_nb_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='P_mean_con', comparison_type='b_nb_70', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='P_mean_con', comparison_type='b_nb_80', df_type='gym', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='V_mean_con', comparison_type='b_nb_70', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='V_mean_con', comparison_type='b_nb_80', df_type='gym', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con_norm', comparison_type='b_nb_70', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con_norm', comparison_type='b_nb_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con', comparison_type='b_nb_70', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con', comparison_type='b_nb_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='P_peak_con', comparison_type='b_nb_70', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='P_peak_con', comparison_type='b_nb_80', df_type='gym', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='V_peak_con', comparison_type='b_nb_70', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='V_peak_con', comparison_type='b_nb_80', df_type='gym', gender='m')
print('=============================================================================================================')
print('')
print('=============================================================================================================')
print('================================ MALE PAIRED TTESTS (70 vs 80) ==============================================')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='F_turning_norm', comparison_type='b_70_80', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='F_turning_norm', comparison_type='nb_70_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='F_turning', comparison_type='b_70_80', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='F_turning', comparison_type='nb_70_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='t_ecc', comparison_type='b_70_80', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='t_ecc', comparison_type='nb_70_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='t_con', comparison_type='b_70_80', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='t_con', comparison_type='nb_70_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='tpP', comparison_type='b_70_80', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='tpP', comparison_type='nb_70_80', df_type='gym', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='tpV', comparison_type='b_70_80', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='tpV', comparison_type='nb_70_80', df_type='gym', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con_norm', comparison_type='b_70_80', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con_norm', comparison_type='nb_70_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con', comparison_type='b_70_80', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='mean_F_con', comparison_type='nb_70_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='P_mean_con', comparison_type='b_70_80', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='P_mean_con', comparison_type='nb_70_80', df_type='gym', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='V_mean_con', comparison_type='b_70_80', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='V_mean_con', comparison_type='nb_70_80', df_type='gym', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con_norm', comparison_type='b_70_80', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con_norm', comparison_type='nb_70_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con', comparison_type='b_70_80', df_type='fp', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='peak_F_con', comparison_type='nb_70_80', df_type='fp', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='P_peak_con', comparison_type='b_70_80', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='P_peak_con', comparison_type='nb_70_80', df_type='gym', gender='m')
print('=============================================================================================================')
insight.run_statistics(analysis_type='ttest', metric='V_peak_con', comparison_type='b_70_80', df_type='gym', gender='m')
print('')
insight.run_statistics(analysis_type='ttest', metric='V_peak_con', comparison_type='nb_70_80', df_type='gym', gender='m')
print('=============================================================================================================')
# Out:
# ...
# ================================ MALE PAIRED TTESTS (Bounce vs No Bounce) ===================================
# ...
# group  bounce70b  bounce70nb
# count  20.000000   20.000000
# mean    1.589168    1.334186
# std     0.163262    0.092532
# min     1.268271    1.154521
# 25%     1.455208    1.291149
# 50%     1.591019    1.336270
# 75%     1.716196    1.375830
# max     1.873422    1.554142
# Homogeneity of variances assumption is not met.
# Normality assumption is met for both groups.
# Assumptions not met for paired t-test. Using Wilcoxon signed-rank test instead.
# Wilcoxon Signed-Rank Test for F_turning_norm: statistic = 0.0, p-value = 1.9073486328125e-06
#
# group  bounce80b  bounce80nb
# count  20.000000   20.000000
# mean    1.481922    1.277310
# std     0.146925    0.075581
# min     1.187362    1.122316
# 25%     1.364919    1.229333
# 50%     1.514658    1.282671
# 75%     1.592234    1.315814
# max     1.763821    1.403792
# Homogeneity of variances assumption is not met.
# ...
